# %%
import sys
import os
from pathlib import Path
root_dir = Path.cwd().parent
if str(root_dir) not in sys.path:
    sys.path.append(str(root_dir))

# %%
from src.pipeline.weather.config import HOURLY_VARIABLES_HIST, URL_WEATHER_FORECAST, MINUTELY_15_VARIABLES_HIST

# %%
import requests
url = URL_WEATHER_FORECAST
params = {
	"latitude": 52.52,
	"longitude": 13.41,
	"current": MINUTELY_15_VARIABLES_HIST,
}
r = requests.get(url, params=params)

# %%
data = r.json()
data
# Out:
# {'latitude': 52.52,
#  'longitude': 13.419998,
#  'generationtime_ms': 0.0934600830078125,
#  'utc_offset_seconds': 0,
#  'timezone': 'GMT',
#  'timezone_abbreviation': 'GMT',
#  'elevation': 38.0,
#  'current_units': {'time': 'iso8601',
#   'interval': 'seconds',
#   'temperature_2m': '°C',
#   'wind_speed_80m': 'km/h',
#   'wind_direction_80m': '°',
#   'snowfall': 'cm',
#   'precipitation': 'mm',
#   'shortwave_radiation': 'W/m²',
#   'direct_radiation': 'W/m²',
#   'diffuse_radiation': 'W/m²'},
#  'current': {'time': '2026-03-05T15:15',
#   'interval': 900,
#   'temperature_2m': 13.5,
#   'wind_speed_80m': 12.8,
#   'wind_direction_80m': 122,
#   'snowfall': 0.0,
#   'precipitation': 0.0,
#   'shortwave_radiation': 191.0,
#   'direct_radiation': 122.0,
#   'diffuse_radiation': 69.0}}

# %%
import pandas as pd
# 1. 先把整个 hourly 部分转成 DataFrame
df_all = pd.DataFrame(data['minutely_15'])

# 2. 从中挑选你需要的列（注意这里是两层中括号，外层是索引，内层是列表）
df = df_all[['time', 'wind_speed_80m', 'wind_direction_80m']]

print(df.head())
# Out:
#                time  wind_speed_80m  wind_direction_80m
# 0  2026-03-05T00:00             9.4                  86
# 1  2026-03-05T00:15             9.0                  90
# 2  2026-03-05T00:30             8.0                  98
# 3  2026-03-05T00:45             7.2                 108
# 4  2026-03-05T01:00             7.1                 114

# %%
print(URL_WEATHER_FORECAST)
# Out:
# https://api.open-meteo.com/v1/forecast
